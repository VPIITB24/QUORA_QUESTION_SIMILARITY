# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <title>Quora Duplicate Question Pair Detection</title>
#   <style>
#     * {
#       box-sizing: border-box;
#     }
#
#     body {
#       font-family: 'Roboto', 'Helvetica Neue', Arial, sans-serif;
#       margin: 0;
#       padding: 0;
#       background: linear-gradient(135deg, #4a90e2 0%, #ff6b6b 50%);
#       background-attachment: fixed;
#       color: #2d3436;
#       line-height: 1.7;
#       min-height: 100vh;
#     }
#
#     h1 {
#       text-align: center;
#       color: #ffffff; /* Updated to white for visibility */
#       font-size: 3.5em;
#       padding: 40px 10px 20px;
#       text-transform: uppercase;
#       letter-spacing: 2px;
#       text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.4);
#       margin: 0;
#     }
#
#     .container {
#       background: rgba(255, 255, 255, 0.95);
#       border-radius: 15px;
#       padding: 30px;
#       box-shadow: 0 10px 25px rgba(0, 0, 0, 0.15);
#       max-width: 95%;
#       margin: auto;
#       margin-bottom: 40px;
#     }
#
#     table {
#       width: 100%;
#       border-collapse: separate;
#       border-spacing: 0;
#       border-radius: 10px;
#       overflow: hidden;
#     }
#
#     th, td {
#       padding: 18px 20px;
#       text-align: left;
#       border-bottom: 1px solid #dfe6e9;
#       transition: background-color 0.3s ease, transform 0.2s ease;
#     }
#
#     th {
#       background: linear-gradient(90deg, #2d3436, #636e72);
#       color: #fff;
#       font-size: 1.1em;
#       text-transform: uppercase;
#       letter-spacing: 1.2px;
#     }
#
#     td {
#       background: #fff;
#       color: #2d3436;
#     }
#
#     tr:last-child td {
#       border-bottom: none;
#     }
#
#     tr:hover td {
#       background: #e3f2fd;
#       transform: translateY(-2px);
#     }
#
#     ul {
#       margin: 0;
#       padding-left: 25px;
#       list-style-type: disc;
#       color: #2d3436;
#     }
#
#     ul li {
#       margin-bottom: 10px;
#     }
#
#     .highlight {
#       color: #d63031;
#       font-weight: 600;
#     }
#
#     .footer {
#       text-align: center;
#       margin: 20px;
#       font-size: 1em;
#       color: #ffffff;
#       text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.2);
#     }
#
#     .footer p {
#       margin: 5px 0;
#       font-weight: 600;
#     }
#
#     @keyframes slideIn {
#       from { opacity: 0; transform: translateY(30px); }
#       to { opacity: 1; transform: translateY(0); }
#     }
#
#     .container {
#       animation: slideIn 1.2s ease-out;
#     }
#
#     @media (max-width: 768px) {
#       h1 {
#         font-size: 2em;
#         padding: 30px 10px 15px;
#       }
#
#       .container {
#         padding: 20px;
#       }
#
#       th, td {
#         padding: 12px;
#       }
#     }
#   </style>
# </head>
# <body>
#   <h1>Quora Duplicate Question Pair Detection</h1>
#
#   <div class="container">
#     <table>
#       <tr>
#         <th>Section</th>
#         <th>Details</th>
#       </tr>
#       <tr>
#         <td><strong>Objective</strong></td>
#         <td>Develop an <span class="highlight">NLP model</span> to detect duplicate question pairs on Quora, optimizing content organization by identifying semantic equivalence across diverse phrasing.</td>
#       </tr>
#       <tr>
#         <td><strong>Dataset</strong></td>
#         <td>484,298 question pairs, sampled to <span class="highlight">38,080</span>. Columns: id, qid1, qid2, question1, question2, is_duplicate (1 = duplicate, 0 = non-duplicate). <span class="highlight">36.92%</span> duplicates.</td>
#       </tr>
#       <tr>
#         <td><strong>Challenges</strong></td>
#         <td>
#           <ul>
#             <li>Semantic similarity detection</li>
#             <li>Handling varied wording</li>
#             <li>Mitigating <span class="highlight">class imbalance</span></li>
#           </ul>
#         </td>
#       </tr>
#       <tr>
#         <td><strong>Methodology</strong></td>
#         <td>
#           <ul>
#             <li><strong>EDA</strong>: Removed missing values; analyzed class distribution.</li>
#             <li><strong>Preprocessing</strong>: Tokenization, stemming (NLTK), Word2Vec embeddings.</li>
#             <li><strong>Modeling</strong>: LSTM/GRU (TensorFlow/Keras), XGBoost classifier.</li>
#             <li><strong>Evaluation</strong>: Precision-optimized with <span class="highlight">0.7 threshold</span> for LSTM.</li>
#           </ul>
#         </td>
#       </tr>
#       <tr>
#         <td><strong>Tools</strong></td>
#         <td>Pandas, NumPy, NLTK, Gensim, <span class="highlight">TensorFlow</span>, Keras, XGBoost, Matplotlib, Seaborn</td>
#       </tr>
#       <tr>
#         <td><strong>Significance</strong></td>
#         <td>Highlights expertise in <span class="highlight">NLP</span> and machine learning, with applications in content moderation and search optimization.</td>
#       </tr>
#     </table>
#   </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <title>Machine Learning Pipeline</title>
#   <style>
#     * {
#       box-sizing: border-box;
#       margin: 0;
#       padding: 0;
#     }
#
#     body {
#       font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#       background: linear-gradient(to right, #4facfe, #00f2fe);
#       color: #2c3e50;
#       padding: 40px 20px;
#       min-height: 100vh;
#     }
#
#     h1 {
#       text-align: center;
#       color: white;
#       font-size: 3em;
#       margin-bottom: 40px;
#       text-shadow: 2px 2px 4px rgba(0,0,0,0.4);
#     }
#
#     .section-container {
#       max-width: 1200px;
#       margin: auto;
#       display: grid;
#       grid-template-columns: repeat(auto-fit, minmax(280px, 1fr));
#       gap: 25px;
#     }
#
#     .section-card {
#       background: white;
#       padding: 25px;
#       border-radius: 15px;
#       box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#       transition: transform 0.3s ease, box-shadow 0.3s ease;
#       animation: fadeInUp 0.6s ease forwards;
#       opacity: 0;
#     }
#
#     .section-card:hover {
#       transform: translateY(-5px);
#       box-shadow: 0 12px 25px rgba(0,0,0,0.2);
#     }
#
#     .section-card h2 {
#       color: #2980b9;
#       margin-bottom: 10px;
#       font-size: 1.4em;
#       text-transform: uppercase;
#       letter-spacing: 1px;
#     }
#
#     .section-card p {
#       font-size: 1em;
#       line-height: 1.6;
#     }
#
#     @keyframes fadeInUp {
#       from {
#         opacity: 0;
#         transform: translateY(20px);
#       }
#       to {
#         opacity: 1;
#         transform: translateY(0);
#       }
#     }
#
#     @media (max-width: 768px) {
#       h1 {
#         font-size: 2em;
#       }
#     }
#   </style>
# </head>
# <body>
#
#   <h1>Machine Learning Workflow</h1>
#
#   <div class="section-container">
#     <div class="section-card">
#       <h2>Dataset Overview and Understanding</h2>
#       <p>Gain an initial understanding of the dataset, including structure, data types, and target variable distribution.</p>
#     </div>
#     <div class="section-card">
#       <h2>Importing Libraries</h2>
#       <p>Load necessary Python libraries such as Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, and TensorFlow.</p>
#     </div>
#     <div class="section-card">
#       <h2>Data Collection</h2>
#       <p>Collect or load data from available sources such as CSV files, databases, or APIs.</p>
#     </div>
#     <div class="section-card">
#       <h2>Exploratory Data Analysis (EDA)</h2>
#       <p>Use visualization and summary statistics to explore relationships, patterns, and anomalies in the data.</p>
#     </div>
#     <div class="section-card">
#       <h2>Data Preprocessing</h2>
#       <p>Clean the data, handle missing values, encode categorical variables, scale numerical features, and prepare for modeling.</p>
#     </div>
#     <div class="section-card">
#       <h2>Model Development</h2>
#       <p>Train various machine learning or deep learning models using training data to find the best performing algorithms.</p>
#     </div>
#     <div class="section-card">
#       <h2>Model Evaluation</h2>
#       <p>Evaluate model performance using metrics like accuracy, F1-score, precision, recall, AUC-ROC, and confusion matrix.</p>
#     </div>
#     <div class="section-card">
#       <h2>Final Model Training</h2>
#       <p>Retrain the best model with optimal parameters on the full training dataset for deployment.</p>
#     </div>
#     <div class="section-card">
#       <h2>Model Deployment</h2>
#       <p>Deploy the model using web frameworks or APIs such as Flask, FastAPI, or cloud services (AWS, Azure, GCP).</p>
#     </div>
#   </div>
#
# </body>
# </html>

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#  Importing Libraries
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM,GRU, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2025-08-06 01:36:56.434752: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#  Data Collection
# </div>

# %%
# Import tha dataset
data= pd.read_csv("/Users/mac/Desktop/DATA/NLP_project.csv")
print("shape of the data is :", data.shape)
data.head(5)
df= data.sample(404290, random_state=42)
# Out:
# shape of the data is : (404290, 6)

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#  EDA
# </div>

# %%
# Information about the data
print("Information about the data is :")
df.info()
# Out:
# Information about the data is :
# <class 'pandas.core.frame.DataFrame'>
# Index: 404290 entries, 8067 to 121958
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 21.6+ MB

# %%
# Descriptive statistics 
print("Descriptive statistics of the data is : ")
df.describe()
# Out:
# Descriptive statistics of the data is :
#                   id           qid1           qid2   is_duplicate
# count  404290.000000  404290.000000  404290.000000  404290.000000
# mean   202144.500000  217243.942418  220955.655337       0.369198
# std    116708.614502  157751.700002  159903.182629       0.482588
# min         0.000000       1.000000       2.000000       0.000000
# 25%    101072.250000   74437.500000   74727.000000       0.000000
# 50%    202144.500000  192182.000000  197052.000000       0.000000
# 75%    303216.750000  346573.500000  354692.500000       1.000000
# max    404289.000000  537932.000000  537933.000000       1.000000

# %%
# Missing values
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# remove missing values
df.dropna(inplace= True)

# %%
# Duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# Distribution of the duplicate and non-duplicate questions

print(df['is_duplicate'].value_counts())
print(" duplicate and non duplicate in percentage is :", df['is_duplicate'].value_counts()/ df['is_duplicate'].count()*100)

df['is_duplicate'].value_counts().plot(kind='bar',color='green')
# Out:
# is_duplicate
# 0    255024
# 1    149263
# Name: count, dtype: int64
#  duplicate and non duplicate in percentage is : is_duplicate
# 0    63.079941
# 1    36.920059
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>

# %%
# Repeated questions
qid=pd.Series(df['qid1'].tolist()+ df['qid2'].tolist())
print("Number  of unique questions is :", np.unique(qid).shape[0])
x = qid.value_counts()>1
print("Number  of repeated questions is :", x[x].shape[0])
# Out:
# Number  of unique questions is : 537929
# Number  of repeated questions is : 111778

# %%
# Repeated questions Histogram Plot 
plt.Figure(figsize=(10,6))
plt.hist(qid.value_counts().values ,bins=100)
plt.yscale('log')
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#  Text Preprocessing
# </div>

# %%
# Preprocessing the text data

def preprocessing(q):
    q = str(q).lower().strip()
# Replacing certain special characters with their string equivalents
    q = q.replace('%','percent')
    q = q.replace('$','dollar')
    q = q.replace('&','and')
    q = q.replace('>','greater than')
    q = q.replace('<','less than')
    q = q.replace('@','at')
    q = q.replace('=','equals')

# Removing the Math patterns from the text
    q = q.replace('[math]',' ')

# Replacing the some numbers with string equivalents

    import re

    q = re.sub(',000,000,000', 'b', q)
    q = re.sub(',000,000', 'm', q)
    q = re.sub(',000', 'k', q)
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)

# Decontracting the contractions

contractions = { 
"ain't": "am not / are not / is not / has not / have not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is / how does",
"I'd": "I had / I would",
"I'd've": "I would have",
"I'll": "I shall / I will",
"I'll've": "I shall have / I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}

def preprocess(q):
    q_decontracted = []

    for word in str(q).split(): 
        if word in contractions:
            word = contractions[word]
        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have") 
    q = q.replace("n't", " not")
    q = q.replace("'r", 'are')

    # Removing HTML tags
    from bs4 import BeautifulSoup
    q = BeautifulSoup(q, "lxml").get_text()

    # Remove punctuation
    import re
    pattern = re.compile('\W')
    q = re.sub(pattern, ' ', q).strip()

    return q

# %%
 # using example we see this code work fine
preprocess(" I'v already! wasn't <b>done</>?")
# Out:
# 'I v already  was not done'

# %%
# Processing the Questions
df['question1']=df['question1'].apply(preprocess)
df['question2']=df['question2'].apply(preprocess)

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#  Feature Engineering
# </div>

# %%
# Feature Engineering
df['q1_len']= df['question1'].str.len()
df['q2_len']= df['question2'].str.len()

# %%
# 1. Combine and tokenize both questions
ques_df=df[['question1','question2']]
questions = list(ques_df['question1'].astype(str)) + list(ques_df['question2'].astype(str))
tokenized_questions = [q.split() for q in questions]
print(" Tokenized Questions :",tokenized_questions[0])
# Out:
#  Tokenized Questions : ['How', 'do', 'I', 'play', 'Pokémon', 'GO', 'in', 'Korea']

# %%
# Creating new features as count number of words in the questions
df['q1_num_words'] = df['question1'].apply(lambda row: len(str(row).split()) )
df['q2_num_words'] = df['question2'].apply(lambda row: len(str(row).split()) )
df.head()
# Out:
#             id    qid1    qid2  \
# 8067      8067   15738   15739
# 368101  368101   12736  104117
# 70497    70497  121486  121487
# 226567  226567  254474  258192
# 73186    73186   48103    3062
#
#                                                 question1  \
# 8067                    How do I play Pokémon GO in Korea
# 368101  What are some of the best side dishes for crab...
# 70497   Which is more advisable and better material fo...
# 226567        How do I improve logical programming skills
# 73186               How close we are to see 3rd world war
#
#                                                 question2  is_duplicate  \
# 8067                    How do I play Pokémon GO in China             0
# 368101  What are some good side dishes for buffalo chi...             0
# 70497        What is the best server setup for buddypress             0
# 226567  How can I improve my logical skills for progra...             1
# ...

# %%
# making new features as word_common between two questions
def common_words(row):
    w1= set(map(lambda word : word.lower().strip(), row['question1'].split(" ")))
    w2= set(map(lambda word : word.lower().strip(), row['question2'].split(" ")))
    return len(w1 & w2 )

# %%
def common_words(row):
	q1 = row['question1']
	q2 = row['question2']

	w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
	w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))
	return len(w1 & w2)

df['word_common'] = df.apply(common_words, axis=1)

# %%
# # making new features as "Total_word" between two questions
def total_words(row):
    w1= set(map(lambda word : word.lower().strip(), row['question1'].split(" ")))
    w2= set(map(lambda word : word.lower().strip(), row['question2'].split( " ")))
    return (len(w1) +len(w2))
df['total_word']= df.apply( total_words, axis =1)

# %%
#  making new features as "Word_share" between two questions
df['word_share'] = round(df['word_common']/ df['total_word'],2)

# %%
# Analysis of new add features
sns.histplot(df['q1_len'])
plt.title(' Question1 Length Distribution')
print('minimum character length in question1 is :', df['q1_len'].min())
print('maximum character length in question1 is :', df['q1_len'].max())
print('average character characters ', int(df['q1_len'].mean()))
# Out:
# minimum character length in question1 is : 0
# maximum character length in question1 is : 621
# average character characters  58

# %%
sns.histplot(df['q2_len'])
plt.title(' Question2 Length Distribution')
print('minimum character length in question1 is :', df['q2_len'].min())
print('maximum character length in question1 is :', df['q2_len'].max())
print('average character characters ', int(df['q2_len'].mean()))
# Out:
# minimum character length in question1 is : 0
# maximum character length in question1 is : 1170
# average character characters  59

# %%
sns.histplot(df['q1_num_words'])
plt.title(' Question1 Words count Distribution')
print('minimum word  in question1 is :', df['q1_num_words'].min())
print('maximum word  in question1 is :', df['q1_num_words'].max())
print('average  numbers of words in question1 is : ', int(df['q1_num_words'].mean()))
# Out:
# minimum word  in question1 is : 0
# maximum word  in question1 is : 128
# average  numbers of words in question1 is :  11

# %%
sns.histplot(df['q2_num_words'])
plt.title(' Question2 Word Count  Distribution')
print('minimum word  in question2 is :', df['q2_num_words'].min())
print('maximum word  in question2 is :', df['q2_num_words'].max())
print('average  numbers of words in question2 is : ', int(df['q2_num_words'].mean()))
# Out:
# minimum word  in question2 is : 0
# maximum word  in question2 is : 249
# average  numbers of words in question2 is :  11

# %%
# common words
sns.distplot(df[df['is_duplicate']==0]['word_common'],label =' non duplicate')
sns.distplot(df[df['is_duplicate']==1]['word_common'],label ='  duplicate')
plt.legend()
plt.show()

# %%
sns.distplot(df[df['is_duplicate']==0]['total_word'],label =' non duplicate')
sns.distplot(df[df['is_duplicate']==1]['total_word'],label =' duplicate')
plt.legend()
plt.show()

# %%
# word share PLots
sns.distplot(df[df['is_duplicate']==0]['word_share'],label =' non duplicate')
sns.distplot(df[df['is_duplicate']==1]['word_share'],label =' duplicate')
plt.legend()
plt.show()

# %%
# Length based features
import distance

def fetch_length_features(row):
    q1 = row['question1']
    q2 = row['question2']
    
    length_features = [0.0] * 3
    
    # converting the sentences into terms
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    # Absolute length features 
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))
    
    # Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens)) / 2
    
    # Longest Common Substring length normalized
    lcs = list(distance.lcsubstrings(q1, q2))
    if lcs and min(len(q1), len(q2)) > 0:
        length_features[2] = len(lcs[0]) / (min(len(q1), len(q2)) + 1)
    else:
        length_features[2] = 0.0
    
    return length_features

# %%
length_features = df.apply(fetch_length_features , axis=1)

df['abs_length_diff']= list(map(lambda x: x[0], length_features))

df['mean_length']= list(map(lambda x: x[1], length_features))

df['longest_substr_ratio']= list(map(lambda x : x[2], length_features))

# %%
# Fuzzy Features
from fuzzywuzzy import fuzz

def fetch_fuzzy_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    fuzzy_features = [0.0]*4
    
    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
fuzzy_features = df.apply(fetch_fuzzy_features, axis=1)

# Creating new feature columns for fuzzy features
df['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
df['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
df['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
df['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %%
# Advanced Features
from nltk.corpus import stopwords

def fetch_token_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    SAFE_DIV = 0.0001 

    STOP_WORDS = stopwords.words("english")
    
    token_features = [0.0]*8
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])
    
    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])
    
    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))
    
    
    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features

# %%
token_features = df.apply(fetch_token_features, axis=1)

df["cwc_min"]       = list(map(lambda x: x[0], token_features))
df["cwc_max"]       = list(map(lambda x: x[1], token_features))
df["csc_min"]       = list(map(lambda x: x[2], token_features))
df["csc_max"]       = list(map(lambda x: x[3], token_features))
df["ctc_min"]       = list(map(lambda x: x[4], token_features))
df["ctc_max"]       = list(map(lambda x: x[5], token_features))
df["last_word_eq"]  = list(map(lambda x: x[6], token_features))
df["first_word_eq"] = list(map(lambda x: x[7], token_features))

# %%
# plot  of length based features

sns.pairplot(df[['mean_length','abs_length_diff','longest_substr_ratio','is_duplicate']],hue= 'is_duplicate')

# %%
df.columns
# Out:
# Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate',
#        'q1_len', 'q2_len', 'q1_num_words', 'q2_num_words', 'word_common',
#        'total_word', 'word_share', 'abs_length_diff', 'mean_length',
#        'longest_substr_ratio', 'fuzz_ratio', 'fuzz_partial_ratio',
#        'token_sort_ratio', 'token_set_ratio', 'cwc_min', 'cwc_max', 'csc_min',
#        'csc_max', 'ctc_min', 'ctc_max', 'last_word_eq', 'first_word_eq'],
#       dtype='object')

# %%
# Using TSNE for Dimentionality reduction for 15 Features(Generated after cleaning the data) to 3 dimentions

from sklearn.preprocessing import MinMaxScaler

X = MinMaxScaler().fit_transform(df[['q1_len', 'q2_len', 'q1_num_words', 'q2_num_words', 'word_common',  'total_word', 'word_share', 'abs_length_diff', 'mean_length',  'longest_substr_ratio']])
y = df['is_duplicate'].values

# %%
from sklearn.manifold import TSNE
tsne2d = TSNE(
    n_components=2,
    init='random',  # 'pca' can be used for faster convergence
    random_state=101,
    method='barnes_hut',
    n_iter=500,
    verbose=1,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 404287 samples in 2.050s...
# [t-SNE] Computed neighbors for 404287 samples in 113.087s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 404287
# [t-SNE] Computed conditional probabilities for sample 2000 / 404287
# [t-SNE] Computed conditional probabilities for sample 3000 / 404287
# [t-SNE] Computed conditional probabilities for sample 4000 / 404287
# [t-SNE] Computed conditional probabilities for sample 5000 / 404287
# [t-SNE] Computed conditional probabilities for sample 6000 / 404287
# [t-SNE] Computed conditional probabilities for sample 7000 / 404287
# [t-SNE] Computed conditional probabilities for sample 8000 / 404287
# [t-SNE] Computed conditional probabilities for sample 9000 / 404287
# [t-SNE] Computed conditional probabilities for sample 10000 / 404287
# [t-SNE] Computed conditional probabilities for sample 11000 / 404287
# [t-SNE] Computed conditional probabilities for sample 12000 / 404287
# ...

# %%
#  Create DataFrame with reduced dimensions
x_df = pd.DataFrame({
    'x': tsne2d[:, 0],
    'y': tsne2d[:, 1],
    'label': y
})

# %%
sns.set(style="whitegrid")
sns.lmplot(
    data=x_df, 
    x='x', y='y', 
    hue='label', 
    fit_reg=False, 
    height=8, 
    palette="Set1", 
    markers=['s', 'o']
)

plt.title("t-SNE Projection of Features", fontsize=16)
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'qid1', 'qid2', 'question1', 'question2', 'is_duplicate',
#        'q1_len', 'q2_len', 'q1_num_words', 'q2_num_words', 'word_common',
#        'total_word', 'word_share', 'abs_length_diff', 'mean_length',
#        'longest_substr_ratio', 'fuzz_ratio', 'fuzz_partial_ratio',
#        'token_sort_ratio', 'token_set_ratio', 'cwc_min', 'cwc_max', 'csc_min',
#        'csc_max', 'ctc_min', 'ctc_max', 'last_word_eq', 'first_word_eq'],
#       dtype='object')

# %%
ques_df = df[['question1','question2']]
ques_df.head()
# Out:
#                                                 question1  \
# 8067                    How do I play Pokémon GO in Korea
# 368101  What are some of the best side dishes for crab...
# 70497   Which is more advisable and better material fo...
# 226567        How do I improve logical programming skills
# 73186               How close we are to see 3rd world war
#
#                                                 question2
# 8067                    How do I play Pokémon GO in China
# 368101  What are some good side dishes for buffalo chi...
# 70497        What is the best server setup for buddypress
# 226567  How can I improve my logical skills for progra...
# 73186                        How close is a World War III

# %%
final_df_1 = df.drop(columns=['id','qid1','qid2','question1','question2'])
print(final_df_1.shape)
final_df_1.head()
# Out:
# (404287, 23)
#         is_duplicate  q1_len  q2_len  q1_num_words  q2_num_words  word_common  \
# 8067               0      33      33             8             8            7
# 368101             0      52      50            11             9            6
# 70497              0      95      44            16             8            2
# 226567             1      43      51             7             9            6
# 73186              1      37      28             9             7            4
#
#         total_word  word_share  abs_length_diff  mean_length  ...  \
# 8067            16        0.44              0.0          8.0  ...
# 368101          20        0.30              2.0         10.0  ...
# 70497           25        0.08              8.0         12.0  ...
# 226567          16        0.38              2.0          8.0  ...
# 73186           16        0.25              2.0          8.0  ...
#
#         token_sort_ratio  token_set_ratio   cwc_min   cwc_max   csc_min  \
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
# Text Vectorization
# </div>

# %%
# 2. Train Word2Vec with Skip-gram model
vector_size = 300  # adjust as needed
skipgram_model = Word2Vec(sentences=tokenized_questions,
                          vector_size=vector_size,
                          window=5,
                          min_count=1,
                          sg=1,        # sg=1 means Skip-gram
                          workers=4,
                          seed=42)

# 3. Create a function to get average vector for a sentence
def get_sentence_vector(sentence, model, vector_size):
    words = str(sentence).split()
    valid_words = [word for word in words if word in model.wv]
    if not valid_words:
        return np.zeros(vector_size)
    return np.mean([model.wv[word] for word in valid_words], axis=0)

# 4. Apply to both columns
q1_vectors = np.vstack([get_sentence_vector(q, skipgram_model, vector_size) for q in ques_df['question1']])
q2_vectors = np.vstack([get_sentence_vector(q, skipgram_model, vector_size) for q in ques_df['question2']])

# 5. Combine into DataFrame
temp_df1 = pd.DataFrame(q1_vectors, index=ques_df.index)
temp_df2 = pd.DataFrame(q2_vectors, index=ques_df.index)
temp_df = pd.concat([temp_df1, temp_df2], axis=1)

print("Skip-gram Vector Shape:", temp_df.shape)
# Out:
# Skip-gram Vector Shape: (404287, 600)

# %%
final_df= pd.concat([final_df_1,temp_df],axis=1)
print(final_df.shape)
final_df.head()
# Out:
# (404287, 623)
#         is_duplicate  q1_len  q2_len  q1_num_words  q2_num_words  word_common  \
# 8067               0      33      33             8             8            7
# 368101             0      52      50            11             9            6
# 70497              0      95      44            16             8            2
# 226567             1      43      51             7             9            6
# 73186              1      37      28             9             7            4
#
#         total_word  word_share  abs_length_diff  mean_length  ...       290  \
# 8067            16        0.44              0.0          8.0  ... -0.218912
# 368101          20        0.30              2.0         10.0  ... -0.332254
# 70497           25        0.08              8.0         12.0  ... -0.110658
# 226567          16        0.38              2.0          8.0  ... -0.185022
# 73186           16        0.25              2.0          8.0  ...  0.073835
#
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
# Train-Test Split
# </div>

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

X = final_df.drop(columns=['is_duplicate'])  
y = final_df['is_duplicate']                 


# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X.values, y.values, test_size=0.2, random_state=42  
)

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
# Modeling
# </div>

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                            f1_score, confusion_matrix, roc_curve, 
                            roc_auc_score, precision_recall_curve, 
                            average_precision_score)

from xgboost import XGBClassifier
xgb= XGBClassifier()
xgb.fit(X_train,y_train)
y_pred_xgb =xgb.predict(X_test)
accuracy_score(y_test,y_pred_xgb),
# Out:
# (0.8206485443617205,)

# %%
confusion_matrix(y_test,y_pred_xgb)
# Out:
# array([[44118,  6953],
#        [ 7549, 22238]])

# %%
from catboost import CatBoostClassifier
cbc = CatBoostClassifier()
cbc.fit(X_train, y_train)
y_pred_cbc =cbc.predict(X_test)
print("Accuracy of CatBoost:", accuracy_score(y_test, y_pred_cbc))
# Out:
# Learning rate set to 0.121509
# 0:	learn: 0.6414363	total: 1.67s	remaining: 27m 46s
# 1:	learn: 0.6055008	total: 2.64s	remaining: 21m 58s
# 2:	learn: 0.5804315	total: 4.04s	remaining: 22m 23s
# 3:	learn: 0.5587389	total: 5.26s	remaining: 21m 50s
# 4:	learn: 0.5450845	total: 6.15s	remaining: 20m 24s
# 5:	learn: 0.5330168	total: 6.97s	remaining: 19m 15s
# 6:	learn: 0.5222009	total: 8.17s	remaining: 19m 18s
# 7:	learn: 0.5146675	total: 9.3s	remaining: 19m 13s
# 8:	learn: 0.5078658	total: 10.1s	remaining: 18m 34s
# 9:	learn: 0.5025782	total: 10.8s	remaining: 17m 49s
# 10:	learn: 0.4972234	total: 12.1s	remaining: 18m 4s
# 11:	learn: 0.4917829	total: 12.9s	remaining: 17m 39s
# 12:	learn: 0.4877696	total: 14s	remaining: 17m 42s
# 13:	learn: 0.4841288	total: 15s	remaining: 17m 38s
# 14:	learn: 0.4812127	total: 16.4s	remaining: 17m 53s
# 15:	learn: 0.4785685	total: 17.2s	remaining: 17m 36s
# 16:	learn: 0.4755267	total: 19s	remaining: 18m 18s
# ...

# %%
confusion_matrix(y_test,y_pred_cbc)
# Out:
# array([[44712,  6359],
#        [ 7101, 22686]])

# %%
# DNN model apply

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# No reshape needed for DNN (Dense NN)

# Model definition
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # For binary classification
])

# Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=256,  # Larger batch size for big data
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate the model
loss, acc = model.evaluate(X_test, y_test)
print(f"\n✅ DNN Test Accuracy: {acc*100:.2f}%")
# Out:
# Epoch 1/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.6550 - loss: 0.6548 - val_accuracy: 0.7695 - val_loss: 0.4525
# Epoch 2/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 27s 27ms/step - accuracy: 0.7596 - loss: 0.4611 - val_accuracy: 0.7699 - val_loss: 0.4413
# Epoch 3/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.7687 - loss: 0.4465 - val_accuracy: 0.7756 - val_loss: 0.4365
# Epoch 4/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.7753 - loss: 0.4371 - val_accuracy: 0.7845 - val_loss: 0.4275
# Epoch 5/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.7779 - loss: 0.4325 - val_accuracy: 0.7928 - val_loss: 0.4216
# Epoch 6/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.7826 - loss: 0.4261 - val_accuracy: 0.7907 - val_loss: 0.4167
# Epoch 7/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.7839 - loss: 0.4232 - val_accuracy: 0.7962 - val_loss: 0.4106
# Epoch 8/50
# ...

# %%
## APPLY LSTM Learning MODEL 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Masking

X_train_lstm = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Model definition
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(1, X_train.shape[1])))  # mask padded zeros
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # sigmoid for binary classification

# Compile
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train
model.fit(X_train_lstm, y_train, epochs=5, batch_size=32, validation_split=0.2)

# Evaluate
loss, acc = model.evaluate(X_test_lstm, y_test)

print(f"\n✅ LSTM Test Accuracy: {acc*100:.2f}%")
# Out:
# Epoch 1/5
# 8086/8086 ━━━━━━━━━━━━━━━━━━━━ 147s 17ms/step - accuracy: 0.7199 - loss: 0.5033 - val_accuracy: 0.7734 - val_loss: 0.4383
# Epoch 2/5
# 8086/8086 ━━━━━━━━━━━━━━━━━━━━ 113s 14ms/step - accuracy: 0.7664 - loss: 0.4513 - val_accuracy: 0.7829 - val_loss: 0.4236
# Epoch 3/5
# 8086/8086 ━━━━━━━━━━━━━━━━━━━━ 161s 20ms/step - accuracy: 0.7752 - loss: 0.4384 - val_accuracy: 0.7879 - val_loss: 0.4208
# Epoch 4/5
# 8086/8086 ━━━━━━━━━━━━━━━━━━━━ 122s 15ms/step - accuracy: 0.7778 - loss: 0.4358 - val_accuracy: 0.7856 - val_loss: 0.4249
# Epoch 5/5
# 8086/8086 ━━━━━━━━━━━━━━━━━━━━ 94s 12ms/step - accuracy: 0.7797 - loss: 0.4336 - val_accuracy: 0.7882 - val_loss: 0.4210
# 2527/2527 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.7919 - loss: 0.4168
#
# ✅ LSTM Test Accuracy: 79.05%

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
# Model Evaluation
# </div>

# %%
# Model Evaluation Toolkit
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                            f1_score, confusion_matrix, roc_curve, 
                            roc_auc_score, precision_recall_curve, 
                            average_precision_score)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def evaluate_model(model, X_test, y_test, threshold=0.5):
    """
    Comprehensive evaluation of binary classification model
    
    Parameters:
    model -- trained classifier
    X_test -- test features
    y_test -- true labels
    threshold -- classification cutoff (default 0.5)
    """
    # Generate predictions
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred = (y_pred_proba >= threshold).astype(int)
        
    # Calculate metrics
    metrics = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1-score': f1_score(y_test, y_pred),
        'AUC-ROC': roc_auc_score(y_test, y_pred_proba),
        'AUC-PR': average_precision_score(y_test, y_pred_proba)
    }
    
    # Print metrics
    print("┌──────────────────────────────┐")
    print("│       Model Evaluation     │  ")
    print("└──────────────────────────────┘")
    for name, value in metrics.items():
        print(f"{name:>10}: {value:.4f}")
    
    # Visualization
    plt.figure(figsize=(15, 4))
    
    # 1. Confusion Matrix
    plt.subplot(1, 3, 1)
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Not Duplicate', 'Duplicate'],
                yticklabels=['Not Duplicate', 'Duplicate'])
    plt.title('Confusion Matrix')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    
    # 2. ROC Curve
    plt.subplot(1, 3, 2)
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    plt.plot(fpr, tpr, label=f'AUC = {metrics["AUC-ROC"]:.2f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.title('ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc="lower right")
    
    # 3. Precision-Recall Curve
    plt.subplot(1, 3, 3)
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    plt.plot(recall, precision, label=f'AP = {metrics["AUC-PR"]:.2f}')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.title('Precision-Recall Curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend(loc="lower left")
    
    plt.tight_layout()
    plt.show()
    
    return metrics

# %%
# XGBoost/LightGBM
from xgboost import XGBClassifier
model = XGBClassifier().fit(X_train, y_train)
evaluate_model(model, X_test, y_test, threshold=0.5)
# Out:
# ┌──────────────────────────────┐
# │       Model Evaluation     │
# └──────────────────────────────┘
#   Accuracy: 0.8206
#  Precision: 0.7618
#     Recall: 0.7466
#   F1-score: 0.7541
#    AUC-ROC: 0.9065
#     AUC-PR: 0.8427
# {'Accuracy': 0.8206485443617205,
#  'Precision': 0.7618101469631051,
#  'Recall': 0.7465672944573136,
#  'F1-score': 0.7541117026687918,
#  'AUC-ROC': 0.9065263730156108,
#  'AUC-PR': 0.8426995556747917}

# %%
# catboost 
evaluate_model(cbc, X_test, y_test, threshold=0.5)
# Out:
# ┌──────────────────────────────┐
# │       Model Evaluation     │
# └──────────────────────────────┘
#   Accuracy: 0.8335
#  Precision: 0.7811
#     Recall: 0.7616
#   F1-score: 0.7712
#    AUC-ROC: 0.9166
#     AUC-PR: 0.8597
# {'Accuracy': 0.8335353335477009,
#  'Precision': 0.7810638664141849,
#  'Recall': 0.7616074126296707,
#  'F1-score': 0.7712129453358716,
#  'AUC-ROC': 0.9165635271061691,
#  'AUC-PR': 0.8597147505213796}

# %%
# To prioritize precision (reduce false duplicates)
evaluate_lstm(model, X_test, y_test, threshold=0.7)
# Out:
#                precision    recall  f1-score   support
#
# Not Duplicate       0.77      0.80      0.78     51071
#     Duplicate       0.63      0.58      0.60     29787
#
#      accuracy                           0.72     80858
#     macro avg       0.70      0.69      0.69     80858
#  weighted avg       0.72      0.72      0.72     80858

# %% [markdown]
# <div style="background: linear-gradient(to right, #6a11cb, #2575fc);
#             color: white; padding: 20px; border-radius: 15px;
#             text-align: center; font-size: 15 px; font-weight: bold;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
# Final Model Training
# </div>

# %%
from xgboost import XGBClassifier
xgb= XGBClassifier()
xgb.fit(X_train,y_train)
y_pred =xgb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
def get_sentence_vector(sentence, model, vector_size=300):
    words = str(sentence).split()
    valid_words = [word for word in words if word in model.wv]
    if not valid_words:
        return np.zeros(vector_size)
    return np.mean([model.wv[word] for word in valid_words], axis=0)

# %%
def test_common_words(q1, q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))    
    return len(w1 & w2)

def test_total_words(q1, q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))    
    return (len(w1) + len(w2))

from difflib import SequenceMatcher as distance  # for longest common substring
def test_fetch_length_features(q1, q2):
    length_features = [0.0]*3
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))  # absolute diff
    length_features[1] = (len(q1_tokens) + len(q2_tokens)) / 2  # avg length
    match = distance(None, q1, q2).find_longest_match(0, len(q1), 0, len(q2))
    length_features[2] = match.size / (min(len(q1), len(q2)) + 1)  # normalized lcs

    return length_features

# %%
def query_point_creator(q1, q2):
    input_query = []
    
    # Preprocess
    q1 = preprocess(q1)
    q2 = preprocess(q2)
    
    # Basic features
    input_query.append(len(q1))
    input_query.append(len(q2))
    
    input_query.append(len(q1.split()))
    input_query.append(len(q2.split()))
    
    common = test_common_words(q1, q2)
    total = test_total_words(q1, q2)
    
    input_query.append(common)
    input_query.append(total)
    input_query.append(round(common / (total + 1e-6), 2))  # avoid division by zero

    # Length-based features
    length_features = test_fetch_length_features(q1, q2)
    input_query.extend(length_features)  # adds 3 features

    # Word2Vec average sentence embeddings
    q1_vec = get_sentence_vector(q1, skipgram_model, vector_size=300).reshape(1, -1)
    q2_vec = get_sentence_vector(q2, skipgram_model, vector_size=300).reshape(1, -1)

    # Final feature vector (10 base + 300 + 300)
    full_vector = np.hstack((np.array(input_query).reshape(1, -1), q1_vec, q2_vec))

    return full_vector

# %%
q1 = 'Where is the capital of India?'
q2 = 'What is the current capital of Pakistan?'
q3 = 'Which city serves as the capital of India?'
q4 = 'What is the business capital of India?'

# %%
xgb.predict(query_point_creator(q1,q4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 xgb.predict(query_point_creator(q1,q4))
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/xgboost/sklearn.py:1718, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1707 @_deprecate_positional_args
#    1708 def predict(
#    1709     self,
#    (...)
#    1715     iteration_range: Optional[IterationRange] = None,
#    1716 ) -> ArrayLike:
#    1717     with config_context(verbosity=self.verbosity):
# -> 1718         class_probs = super().predict(
#    1719             X=X,
# ...
